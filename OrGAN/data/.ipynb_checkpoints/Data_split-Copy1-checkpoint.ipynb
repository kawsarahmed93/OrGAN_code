# %%
import os
import random
import shutil
import numpy as np

# %%
path_train="./Train/Xray"
X = os.listdir(path_train)
X = [x for x in X if 'Luna16' in x]

# %%
X[0][12:-4]
# Out:
# '103'

# %%
path = './Xray'
Y = os.listdir(path)
Z = []
for x in X:
    Z.append([z for z in Y if z[14:-4] == x[12:-4]])
# Out:
# [['Luna16_Xray_n_103.npy'],
#  ['Luna16_Xray_n_776.npy'],
#  ['Luna16_Xray_n_782.npy'],
#  ['Luna16_Xray_n_676.npy'],
#  ['Luna16_Xray_n_92.npy'],
#  ['Luna16_Xray_n_331.npy'],
#  ['Luna16_Xray_n_543.npy'],
#  ['Luna16_Xray_n_643.npy'],
#  ['Luna16_Xray_n_708.npy'],
#  ['Luna16_Xray_n_819.npy'],
#  ['Luna16_Xray_n_222.npy'],
#  ['Luna16_Xray_n_468.npy'],
#  ['Luna16_Xray_n_23.npy'],
#  ['Luna16_Xray_n_517.npy'],
#  ['Luna16_Xray_n_472.npy'],
#  ['Luna16_Xray_n_609.npy'],
#  ['Luna16_Xray_n_657.npy'],
#  ['Luna16_Xray_n_12.npy'],
#  ['Luna16_Xray_n_89.npy'],
#  ['Luna16_Xray_n_476.npy'],
#  ['Luna16_Xray_n_322.npy'],
#  ['Luna16_Xray_n_450.npy'],
#  ['Luna16_Xray_n_21.npy'],
#  ['Luna16_Xray_n_732.npy'],
#  ['Luna16_Xray_n_156.npy'],
#  ['Luna16_Xray_n_212.npy'],
#  ['Luna16_Xray_n_719.npy'],
#  ['Luna16_Xray_n_241.npy'],
#  ['Luna16_Xray_n_445.npy'],
#  ['Luna16_Xray_n_541.npy'],
#  ['Luna16_Xray_n_702.npy'],
#  ['Luna16_Xray_n_560.npy'],
#  ['Luna16_Xray_n_236.npy'],
# ...

# %%
# Out:
# 624

# %%
train_X_path = "./Train/Lungs/"
for i in Z:
    source = "./Lungs/Luna16_Lungs_n_"+i[0][14:]
    dest = shutil.move(source, train_X_path)
#dest = shutil.move(source, destination)

# %%
temp = train_X
"./Lungs/Luna16_Lungs_"+temp[0][12:]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2678787/1945706001.py in <module>
# ----> 1 temp = train_X
#       2 "./Lungs/Luna16_Lungs_"+temp[0][12:]
#
# NameError: name 'train_X' is not defined

# %%
train_S_path = "./Train/Soft/"
for i in range(len(train_X)):
    source = "./Soft/Luna16_Soft_"+train_X[i][12:]
    dest = shutil.move(source, train_S_path)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2678787/897133706.py in <module>
#       1 train_S_path = "./Train/Soft/"
# ----> 2 for i in range(len(train_X)):
#       3     source = "./Soft/Luna16_Soft_"+train_X[i][12:]
#       4     dest = shutil.move(source, train_S_path)
#
# NameError: name 'train_X' is not defined

# %%
train_L_path = "./Train/Lungs/"
for i in range(len(train_X)):
    source = "./Lungs/Luna16_Lungs_"+train_X[i][12:]
    dest = shutil.move(source, train_L_path)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2678787/2806615222.py in <module>
#       1 train_L_path = "./Train/Lungs/"
# ----> 2 for i in range(len(train_X)):
#       3     source = "./Lungs/Luna16_Lungs_"+train_X[i][12:]
#       4     dest = shutil.move(source, train_L_path)
#
# NameError: name 'train_X' is not defined

# %%
772*.2
# Out:
# 154.4
